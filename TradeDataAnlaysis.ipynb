# %%
### Trades

# %%
import pandas as pd

# %%
source_data = pd.read_csv("./Day3/Day3_Lab_Environment/data/trade_blotter.csv")

# %%
source_data.head(5)
# Out:
#    trade_id  trade_date  security_id  trader_id trade_type  quantity    price  \
# 0    100224  2026-05-19            1          6       SELL       500  1155.56
# 1    100137  2026-05-13            2          4        BUY      4200  2688.04
# 2    100112  2026-05-11            5          6        BUY      4100  2798.81
# 3    100496  2026-06-09            8          2        BUY      4000  2038.49
# 4    100254  2026-05-22            5          1        BUY      1900  1238.77
#
#       last_modified_ts
# 0  2026-05-19 17:43:00
# 1  2026-05-13 16:59:00
# 2  2026-05-11 16:06:00
# 3  2026-06-09 12:41:00
# 4  2026-05-22 09:55:00

# %%
source_data['trade_value'] = source_data['quantity'] * source_data['price']

# %%
source_data.head(5)
# Out:
#    trade_id  trade_date  security_id  trader_id trade_type  quantity    price  \
# 0    100224  2026-05-19            1          6       SELL       500  1155.56
# 1    100137  2026-05-13            2          4        BUY      4200  2688.04
# 2    100112  2026-05-11            5          6        BUY      4100  2798.81
# 3    100496  2026-06-09            8          2        BUY      4000  2038.49
# 4    100254  2026-05-22            5          1        BUY      1900  1238.77
#
#       last_modified_ts  trade_value
# 0  2026-05-19 17:43:00     577780.0
# 1  2026-05-13 16:59:00   11289768.0
# 2  2026-05-11 16:06:00   11475121.0
# 3  2026-06-09 12:41:00    8153960.0
# 4  2026-05-22 09:55:00    2353663.0

# %%
source_data['trade_value'].sum()
# Out:
# np.float64(3351976785.0)

# %%
source_data.to_csv('updated_trades_data.csv')

# %%
source_data.shape
# Out:
# (567, 9)

# %%
type(source_data['trade_type'][0]).
# Out:
# str

# %%
source_data.dtypes
# Out:
# trade_id              int64
# trade_date           object
# security_id           int64
# trader_id             int64
# trade_type           object
# quantity              int64
# price               float64
# last_modified_ts     object
# trade_value         float64
# dtype: object

# %%
# source_data
