# %%
# !pip install numpy pandas
# Out:
# Requirement already satisfied: numpy in /Users/mousingh/Downloads/Trainings/OakTree/oaktree-phase2-code/op2/lib/python3.9/site-packages (2.0.2)
# Collecting pandas
#   Downloading pandas-2.3.3-cp39-cp39-macosx_11_0_arm64.whl (10.8 MB)
#      |████████████████████████████████| 10.8 MB 8.1 MB/s eta 0:00:01
# Requirement already satisfied: tzdata>=2022.7 in /Users/mousingh/Downloads/Trainings/OakTree/oaktree-phase2-code/op2/lib/python3.9/site-packages (from pandas) (2026.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mousingh/Downloads/Trainings/OakTree/oaktree-phase2-code/op2/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/mousingh/Downloads/Trainings/OakTree/oaktree-phase2-code/op2/lib/python3.9/site-packages (from pandas) (2026.3.post1)
# Requirement already satisfied: six>=1.5 in /Users/mousingh/Downloads/Trainings/OakTree/oaktree-phase2-code/op2/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Installing collected packages: pandas
# Successfully installed pandas-2.3.3
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/mousingh/Downloads/Trainings/OakTree/oaktree-phase2-code/op2/bin/python3 -m pip install --upgrade pip' command.

# %%
import duckdb
con = duckdb.connect("oaktree_local.duckdb")
print(con.execute("SELECT * FROM main.silver_trades LIMIT 5").fetchdf())
print(con.execute("SELECT COUNT(*) FROM main.gold_fact_trades_daily").fetchone())
# Out:
#    trade_id trade_date  security_id  trader_id trade_type  quantity    price  \
# 0    100002 2026-05-01            2          5       SELL     300.0   240.88
# 1    100003 2026-05-01            1          5        BUY    4600.0  2132.15
# 2    100008 2026-05-01            5          6       SELL    3700.0   736.48
# 3    100024 2026-05-04            6          3        BUY     400.0   884.66
# 4    100027 2026-05-04            5          4       SELL    2900.0  2893.82
#
#    trade_value
# 0      72264.0
# 1    9807890.0
# 2    2724976.0
# 3     353864.0
# 4    8392078.0
# (291,)

# %%
import pandas as pd

# %%
pd.read_sql
